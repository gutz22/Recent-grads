# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
% matplotlib inline
# Out:
# UsageError: Line magic function `%` not found.

# %%
recent_grads = pd.read_csv('~/Downloads/data_sets/recent-grads.csv')

# %%
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                  2339.0
# Men                                    2057.0
# Women                                   282.0
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                    0.018381
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
display(recent_grads.head())
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  ...  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976  ...
# 1    679.0     77.0    Engineering    0.101852            7       640  ...
# 2    725.0    131.0    Engineering    0.153037            3       648  ...
# 3   1123.0    135.0    Engineering    0.107313           16       758  ...
# 4  21239.0  11021.0    Engineering    0.341631          289     25694  ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  \
# 168    Biology & Life Science    0.637293           47      6259
# 169  Psychology & Social Work    0.817099            7      2125
# 170  Psychology & Social Work    0.799859           13      2101
# 171  Psychology & Social Work    0.798746           21      3777
# 172                 Education    0.877960            2       742
#
#          ...        Part_time  Full_time_year_round  Unemployed  \
# 168      ...             2190                  3602         304
# ...

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
raw_data_count = recent_grads.shape[0]
raw_data_count
# Out:
# 173

# %%
recent_grads.isnull().sum()
# Out:
# Rank                    0
# Major_code              0
# Major                   0
# Total                   1
# Men                     1
# Women                   1
# Major_category          0
# ShareWomen              1
# Sample_size             0
# Employed                0
# Full_time               0
# Part_time               0
# Full_time_year_round    0
# Unemployed              0
# Unemployment_rate       0
# Median                  0
# P25th                   0
# P75th                   0
# College_jobs            0
# Non_college_jobs        0
# Low_wage_jobs           0
# dtype: int64

# %%
recent_grads.dropna(inplace=True)
recent_grads.isnull().sum()
# Out:
# Rank                    0
# Major_code              0
# Major                   0
# Total                   0
# Men                     0
# Women                   0
# Major_category          0
# ShareWomen              0
# Sample_size             0
# Employed                0
# Full_time               0
# Part_time               0
# Full_time_year_round    0
# Unemployed              0
# Unemployment_rate       0
# Median                  0
# P25th                   0
# P75th                   0
# College_jobs            0
# Non_college_jobs        0
# Low_wage_jobs           0
# dtype: int64

# %%
recent_grads.shape[0]
# Out:
# 172

# %%
recent_grads["Major"].unique
# Out:
# <bound method Series.unique of 0                              PETROLEUM ENGINEERING
# 1                     MINING AND MINERAL ENGINEERING
# 2                          METALLURGICAL ENGINEERING
# 3          NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4                               CHEMICAL ENGINEERING
# 5                                NUCLEAR ENGINEERING
# 6                                  ACTUARIAL SCIENCE
# 7                         ASTRONOMY AND ASTROPHYSICS
# 8                             MECHANICAL ENGINEERING
# 9                             ELECTRICAL ENGINEERING
# 10                              COMPUTER ENGINEERING
# 11                             AEROSPACE ENGINEERING
# 12                            BIOMEDICAL ENGINEERING
# 13                                 MATERIALS SCIENCE
# 14         ENGINEERING MECHANICS PHYSICS AND SCIENCE
# 15                            BIOLOGICAL ENGINEERING
# 16          INDUSTRIAL AND MANUFACTURING ENGINEERING
# ...

# %%
recent_grads.loc[recent_grads['Major'].str.contains(r'COMPUTER')]
# Out:
#      Rank  Major_code                                            Major  \
# 10     11        2407                             COMPUTER ENGINEERING
# 20     21        2102                                 COMPUTER SCIENCE
# 42     43        2100                 COMPUTER AND INFORMATION SYSTEMS
# 52     53        4005                 MATHEMATICS AND COMPUTER SCIENCE
# 53     54        2101         COMPUTER PROGRAMMING AND DATA PROCESSING
# 81     82        2106  COMPUTER ADMINISTRATION MANAGEMENT AND SECURITY
# 84     85        2107       COMPUTER NETWORKING AND TELECOMMUNICATIONS
# 144   145        2308           SCIENCE AND COMPUTER TEACHER EDUCATION
#
#         Total      Men    Women           Major_category  ShareWomen  \
# 10    41542.0  33258.0   8284.0              Engineering    0.199413
# 20   128319.0  99743.0  28576.0  Computers & Mathematics    0.222695
# 42    36698.0  27392.0   9306.0  Computers & Mathematics    0.253583
# ...

# %%
recent_grads.plot("Sample_size", "Median", kind="scatter", logx=True)

# %%
recent_grads.plot("Sample_size", "Unemployment_rate", kind="scatter", logx=True)

# %%
recent_grads.plot("Full_time", "Median", kind="scatter", logx=True)

# %%
recent_grads.plot("ShareWomen", "Unemployment_rate", kind="scatter")

# %%
recent_grads.plot("Men", "Median", kind="scatter", logx=True)

# %%
recent_grads.plot("Women", "Median", kind="scatter")

# %%
recent_grads.sort_values(by="Median", ascending=False)
# Out:
#      Rank  Major_code                                          Major  \
# 0       1        2419                          PETROLEUM ENGINEERING
# 1       2        2416                 MINING AND MINERAL ENGINEERING
# 2       3        2415                      METALLURGICAL ENGINEERING
# 3       4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4       5        2405                           CHEMICAL ENGINEERING
# 5       6        2418                            NUCLEAR ENGINEERING
# 6       7        6202                              ACTUARIAL SCIENCE
# 7       8        5001                     ASTRONOMY AND ASTROPHYSICS
# 10     11        2407                           COMPUTER ENGINEERING
# 13     14        5008                              MATERIALS SCIENCE
# 12     13        2404                         BIOMEDICAL ENGINEERING
# 9      10        2408                         ELECTRICAL ENGINEERING
# 8       9        2414                         MECHANICAL ENGINEERING
# ...

# %%
print(recent_grads["Sample_size"].max())
recent_grads.sort_values(by="Sample_size", ascending=False)
# Out:
# 4212
#      Rank  Major_code                                          Major  \
# 76     77        6203         BUSINESS MANAGEMENT AND ADMINISTRATION
# 77     78        6206               MARKETING AND MARKETING RESEARCH
# 145   146        5200                                     PSYCHOLOGY
# 34     35        6107                                        NURSING
# 93     94        1901                                 COMMUNICATIONS
# 57     58        6200                               GENERAL BUSINESS
# 35     36        6207                                        FINANCE
# 40     41        6201                                     ACCOUNTING
# 94     95        5301           CRIMINAL JUSTICE AND FIRE PROTECTION
# 138   139        2304                           ELEMENTARY EDUCATION
# 137   138        3301                ENGLISH LANGUAGE AND LITERATURE
# 78     79        5506               POLITICAL SCIENCE AND GOVERNMENT
# ...

# %%
recent_grads["Sample_size"].hist(bins=9, range=(0,4500))

# %%
recent_grads["Median"].hist(bins=12, range=(0,120000))

# %%
recent_grads["Employed"].hist(bins=12)

# %%
recent_grads["Full_time"].hist()

# %%
recent_grads["ShareWomen"].hist()

# %%
recent_grads["Unemployment_rate"].hist()

# %%
recent_grads["Men"].hist()

# %%
recent_grads["Women"].hist()

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(recent_grads[["Sample_size","Median"]])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f151f9646d8>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[["Sample_size","Median", "Unemployment_rate"]])
# Out:
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x7f151f3fd9e8>
# ...

# %%
recent_grads["ShareWomen"].head(10)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-1-6bbf8720aaec> in <module>()
# ----> 1 recent_grads["ShareWomen"].head(10)
#
# NameError: name 'recent_grads' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
% matplotlib inline

# %%
recent_grads = pd.read_csv('recent-grads.csv')

# %%
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  \
# 168    Biology & Life Science    0.637293           47      6259
# 169  Psychology & Social Work    0.817099            7      2125
# 170  Psychology & Social Work    0.799859           13      2101
# 171  Psychology & Social Work    0.798746           21      3777
# 172                 Education    0.877960            2       742
#
#          ...        Part_time  Full_time_year_round  Unemployed  \
# 168      ...             2190                  3602         304
# ...

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
raw_data_count = recent_grads.shape[0]
raw_data_count
# Out:
# 173

# %%
recent_grads.isnull().sum()
# Out:
# Rank                    0
# Major_code              0
# Major                   0
# Total                   1
# Men                     1
# Women                   1
# Major_category          0
# ShareWomen              1
# Sample_size             0
# Employed                0
# Full_time               0
# Part_time               0
# Full_time_year_round    0
# Unemployed              0
# Unemployment_rate       0
# Median                  0
# P25th                   0
# P75th                   0
# College_jobs            0
# Non_college_jobs        0
# Low_wage_jobs           0
# dtype: int64

# %%
recent_grads.dropna(inplace=True)
recent_grads.isnull().sum()
# Out:
# Rank                    0
# Major_code              0
# Major                   0
# Total                   0
# Men                     0
# Women                   0
# Major_category          0
# ShareWomen              0
# Sample_size             0
# Employed                0
# Full_time               0
# Part_time               0
# Full_time_year_round    0
# Unemployed              0
# Unemployment_rate       0
# Median                  0
# P25th                   0
# P75th                   0
# College_jobs            0
# Non_college_jobs        0
# Low_wage_jobs           0
# dtype: int64

# %%
recent_grads.shape[0]
# Out:
# 172

# %%
recent_grads["Major"].unique
# Out:
# <bound method Series.unique of 0                              PETROLEUM ENGINEERING
# 1                     MINING AND MINERAL ENGINEERING
# 2                          METALLURGICAL ENGINEERING
# 3          NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4                               CHEMICAL ENGINEERING
# 5                                NUCLEAR ENGINEERING
# 6                                  ACTUARIAL SCIENCE
# 7                         ASTRONOMY AND ASTROPHYSICS
# 8                             MECHANICAL ENGINEERING
# 9                             ELECTRICAL ENGINEERING
# 10                              COMPUTER ENGINEERING
# 11                             AEROSPACE ENGINEERING
# 12                            BIOMEDICAL ENGINEERING
# 13                                 MATERIALS SCIENCE
# 14         ENGINEERING MECHANICS PHYSICS AND SCIENCE
# 15                            BIOLOGICAL ENGINEERING
# 16          INDUSTRIAL AND MANUFACTURING ENGINEERING
# ...

# %%
recent_grads.loc[recent_grads['Major'].str.contains(r'COMPUTER')]
# Out:
#      Rank  Major_code                                            Major  \
# 10     11        2407                             COMPUTER ENGINEERING
# 20     21        2102                                 COMPUTER SCIENCE
# 42     43        2100                 COMPUTER AND INFORMATION SYSTEMS
# 52     53        4005                 MATHEMATICS AND COMPUTER SCIENCE
# 53     54        2101         COMPUTER PROGRAMMING AND DATA PROCESSING
# 81     82        2106  COMPUTER ADMINISTRATION MANAGEMENT AND SECURITY
# 84     85        2107       COMPUTER NETWORKING AND TELECOMMUNICATIONS
# 144   145        2308           SCIENCE AND COMPUTER TEACHER EDUCATION
#
#         Total      Men    Women           Major_category  ShareWomen  \
# 10    41542.0  33258.0   8284.0              Engineering    0.199413
# 20   128319.0  99743.0  28576.0  Computers & Mathematics    0.222695
# 42    36698.0  27392.0   9306.0  Computers & Mathematics    0.253583
# ...

# %%
recent_grads.plot("Sample_size", "Median", kind="scatter", logx=True)

# %%
recent_grads.plot("Sample_size", "Unemployment_rate", kind="scatter", logx=True)

# %%
recent_grads.plot("Full_time", "Median", kind="scatter", logx=True)

# %%
recent_grads.plot("ShareWomen", "Unemployment_rate", kind="scatter")

# %%
recent_grads.plot("Men", "Median", kind="scatter", logx=True)

# %%
recent_grads.plot("Women", "Median", kind="scatter")

# %%
recent_grads.sort_values(by="Median", ascending=False)
# Out:
#      Rank  Major_code                                          Major  \
# 0       1        2419                          PETROLEUM ENGINEERING
# 1       2        2416                 MINING AND MINERAL ENGINEERING
# 2       3        2415                      METALLURGICAL ENGINEERING
# 3       4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4       5        2405                           CHEMICAL ENGINEERING
# 5       6        2418                            NUCLEAR ENGINEERING
# 6       7        6202                              ACTUARIAL SCIENCE
# 7       8        5001                     ASTRONOMY AND ASTROPHYSICS
# 10     11        2407                           COMPUTER ENGINEERING
# 13     14        5008                              MATERIALS SCIENCE
# 12     13        2404                         BIOMEDICAL ENGINEERING
# 9      10        2408                         ELECTRICAL ENGINEERING
# 8       9        2414                         MECHANICAL ENGINEERING
# ...

# %%
print(recent_grads["Sample_size"].max())
recent_grads.sort_values(by="Sample_size", ascending=False)
# Out:
# 4212
#      Rank  Major_code                                          Major  \
# 76     77        6203         BUSINESS MANAGEMENT AND ADMINISTRATION
# 77     78        6206               MARKETING AND MARKETING RESEARCH
# 145   146        5200                                     PSYCHOLOGY
# 34     35        6107                                        NURSING
# 93     94        1901                                 COMMUNICATIONS
# 57     58        6200                               GENERAL BUSINESS
# 35     36        6207                                        FINANCE
# 40     41        6201                                     ACCOUNTING
# 94     95        5301           CRIMINAL JUSTICE AND FIRE PROTECTION
# 138   139        2304                           ELEMENTARY EDUCATION
# 137   138        3301                ENGLISH LANGUAGE AND LITERATURE
# 78     79        5506               POLITICAL SCIENCE AND GOVERNMENT
# ...

# %%
recent_grads["Sample_size"].hist(bins=9, range=(0,4500))

# %%
recent_grads["Median"].hist(bins=12, range=(0,120000))

# %%
recent_grads["Employed"].hist(bins=12)

# %%
recent_grads["Full_time"].hist()

# %%
recent_grads["ShareWomen"].hist()

# %%
recent_grads["Unemployment_rate"].hist()

# %%
recent_grads["Men"].hist()

# %%
recent_grads["Women"].hist()

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(recent_grads[["Sample_size","Median"]])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f151f9646d8>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[["Sample_size","Median", "Unemployment_rate"]])
# Out:
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x7f151f3fd9e8>
# ...

# %%
recent_grads[:10].plot.bar(x="Major", y="ShareWomen", rot=45, figsize=(10,10))
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-1-6bbf8720aaec> in <module>()
# ----> 1 recent_grads["ShareWomen"].head(10)
#
# NameError: name 'recent_grads' is not defined

# %%
recent_grads.tail(10).plot.bar(x="Major", y="ShareWomen", rot=45, figsize=(10,10))

# %%
recent_grads[:10].plot.bar(x="Major", y="Unemployment_rate", rot=45, figsize=(10,10))

# %%
ax = recent_grads.tail(10).plot.bar(x="Major", y="Unemployment_rate",figsize=(10,10))
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45, ha="right")
